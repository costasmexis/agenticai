# %%
import requests

URL = "https://en.wikipedia.org/w/api.php"

headers = {
    "User-Agent": "Learning API"
}

params = {
    "action": "query",
    "format": "json",
    "prop": "extracts",
    "exintro": True,
    "explaintext": True,
    "titles": "Python (programming language)"
}

response = requests.get(URL, params=params, headers=headers)

data = response.json()

pages = data["query"]["pages"]
page = next(iter(pages.values()))
summary = page.get("extract", "No summary available")

print(summary)

# %%
import mwclient

site = mwclient.Site('en.wikipedia.org')
page = site.pages['Butyronitrile']
target = ['MeltingPtC', 'MeltingPtK']

if not page.exists:
    raise RuntimeError("Page not found")

# Follow redirect if present
if page.redirect:
    page = page.redirects_to()

print("Resolved page:", page.name)

wikitext = page.text()

result = None
for line in wikitext.splitlines():
    if target in line:
        result = line.strip()
        break

print("Result:", result)
# Out:
# Resolved page: Butyronitrile
# Result: None

# %%
print(page.text())
# Out:
# {{Chembox
# | Verifiedfields = changed
# | Watchedfields = changed
# | verifiedrevid = 410651538
# | Reference = <ref>''Merck Index'', 11th Edition, '''1597'''</ref>
# | ImageFileL1 = Butyronitrile.png
# | ImageClassL1 = skin-invert-image
# | ImageFileL1_Ref = {{chemboximage|correct|??}}
# | ImageSizeL1 = 115
# | ImageAltL1 = Structural formula of butyronitrile
# | ImageFileR1 = Butyronitrile 3D ball.png
# | ImageClassR1 = bg-transparent
# | ImageSizeR1 = 125
# | ImageAltR1 = Ball-and-stick model of the butyronitrile molecule
# | PIN = Butanenitrile<ref>{{Cite web|title=N-butyronitrile - Compound Summary|url=https://pubchem.ncbi.nlm.nih.gov/compound/8008|work=PubChem Compound|publisher=National Center for Biotechnology Information|access-date=12 June 2012|location=USA|date=26 March 2005|at=Identification}}</ref>
# | OtherNames = {{Unbulleted list|1-Cyanopropane<ref name=PGCH/>|Propyl cyanide<ref name=PGCH/>|''n''-Butyronitrile<ref name=PGCH/>|
# }}
# |Section1={{Chembox Identifiers
# | CASNo = 109-74-0
# | CASNo_Ref = {{cascite|correct|CAS}}
# | UNII_Ref = {{fdacite|correct|FDA}}
# | UNII = O3V36V0W0M
# | PubChem = 8008
# | ChemSpiderID = 7717
# | ChemSpiderID_Ref = {{chemspidercite|changed|chemspider}}
# | EINECS = 203-700-6
# | UNNumber = 2411
# | MeSHName = N-butyronitrile
# | ChEBI = 51937
# | ChEBI_Ref = {{ebicite|changed|EBI}}
# | RTECS = ET8750000
# | Beilstein = 1361452
# | SMILES = CCCC#N
# | StdInChI = 1S/C4H7N/c1-2-3-4-5/h2-3H2,1H3
# | StdInChI_Ref = {{stdinchicite|changed|chemspider}}
# | StdInChIKey = KVNRLNFWIYMESJ-UHFFFAOYSA-N
# | StdInChIKey_Ref = {{stdinchicite|changed|chemspider}}
# }}
# |Section2={{Chembox Properties
# | C=4 | H=7 | N=1
# | Appearance = Colorless
# | Odor = Sharp and suffocating<ref name=PGCH/>
# | Density = 794 mg mL<sup>−1</sup>
# | MeltingPtK = 161.25
# | BoilingPtK = 390.7
# | VaporPressure = 3.1 kPa
# | Solubility = 0.033 g/100 mL
# | SolubleOther = soluble in [[benzene]] <br> miscible in [[ethanol|alcohol]], [[diethyl ether|ether]], [[dimethylformamide]]
# | HenryConstant = 190 μmol Pa<sup>−1</sup> kg<sup>−1</sup>
# | RefractIndex = 1.38385
# | MagSus = −49.4·10<sup>−6</sup> cm<sup>3</sup>/mol
# | Dipole = 3.5
# }}
# |Section3={{Chembox Thermochemistry
# | DeltaHf = −6.8 – −4.8 kJ mol<sup>−1</sup>
# | DeltaHc = −2.579 MJ mol<sup>−1</sup>
# | HeatCapacity = 134.2 J K<sup>−1</sup> mol<sup>−1</sup>
# }}
# |Section4={{Chembox Hazards
# | GHSPictograms = {{GHS flame}} {{GHS skull and crossbones}}
# | GHSSignalWord = '''DANGER'''
# | HPhrases = {{H-phrases|225|301|311|331}}
# | PPhrases = {{P-phrases|210|261|280|301+310|311}}
# | NFPA-H = 3
# | NFPA-F = 3
# | NFPA-R = 0
# | FlashPtC = 18
# | AutoignitionPtC = 488
# | ExploLimits = 1.65%–?<ref name=PGCH/>
# | LD50 = 50 mg kg<sup>−1</sup> <small>(oral, rat)</small>
# | PEL = none<ref name=PGCH>{{PGCH|0086}}</ref>
# | IDLH = N.D.<ref name=PGCH/>
# | REL = TWA 8 ppm (22 mg/m<sup>3</sup>)<ref name=PGCH/>
# }}
# |Section5={{Chembox Related
# | OtherFunction_label = alkanenitriles
# | OtherFunction = {{Unbulleted list|[[Isobutyronitrile]]|[[Propanenitrile]]|[[Malononitrile]]|[[Pivalonitrile]]|[[Succinonitrile]]|[[Glutaronitrile]]}}
# | OtherCompounds =
# }}
# }}
#
# '''Butyronitrile''' or '''butanenitrile''' or '''propyl cyanide''', is a [[nitrile]] with the formula C<sub>3</sub>H<sub>7</sub>CN. This colorless liquid is miscible with most polar organic solvents.
#
# ==Uses==
# Butyronitrile is mainly used as a precursor to the poultry drug [[amprolium]].<ref>Peter Pollak, Gérard Romeder, Ferdinand Hagedorn, Heinz-Peter Gelbke "Nitriles" ''Ullmann's Encyclopedia of Industrial Chemistry'' 2002, Wiley-VCH, Weinheim. {{doi|10.1002/14356007.a17_363}}</ref>
#
# It also has recognized use in the synthesis  of [[Etifelmine]].
# ==Synthesis==
# Butyronitrile is prepared industrially by the [[ammoxidation]] of [[N-Butanol|''n''-butanol]]:
# :C<sub>3</sub>H<sub>7</sub>CH<sub>2</sub>OH  +  NH<sub>3</sub>  +  O<sub>2</sub>   →   C<sub>3</sub>H<sub>7</sub>CN  +  3 H<sub>2</sub>O
#
# == Occurrence in space ==
# Butyronitrile has been detected in the [[Large Molecule Heimat]] in Sagittarius B2 cloud along with other complex organic molecules.<ref name="ras">{{cite web|url=https://www.ras.org.uk/search/article-archive/1609-ras-pn0925nam12two-highly-complex-organic-molecules-detected-in-space-|date=21 April 2009|access-date=29 September 2015|title=Two highly complex organic molecules detected in space|publisher=Royal Astronomical Society}}</ref>
#
# ==References==
# {{Reflist}}
#
# ==External links==
# * [http://webbook.nist.gov/cgi/cbook.cgi?ID=C109740 NIST Chemistry WebBook page for C4H7N]
# * [https://www.cdc.gov/niosh/npg/npgd0086.html CDC - NIOSH Pocket Guide to Chemical Hazards]
#
# {{Molecules detected in outer space}}
#
# [[Category:Alkanenitriles|4]]

# %%
wikitext
# Out:
# '#REDIRECT [[1-Heptadecanol]]\n\n{{Redirect category shell|\n{{R from move}}\n}}'

# %%
import pubchempy as pcp

def name_from_smiles(smiles: str) -> str:
    """
    Given a SMILES string, return the preferred name of the compound
    using PubChem (via PubChemPy).
    """
    # Query PubChem using SMILES → Compound
    compounds = pcp.get_compounds(smiles, namespace='smiles')

    if not compounds:
        raise KeyError(f"No PubChem compound found for SMILES: {smiles}")

    compound = compounds[0]

    # PubChemPy automatically resolves several name fields
    if compound.iupac_name:
        return compound.iupac_name
    if compound.synonyms:
        return compound.synonyms[0]
    if compound.title:
        return compound.title

    raise KeyError(f"Compound found but no name available for SMILES: {smiles}")

print(name_from_smiles("c1ccc2c(c1)ccc3Nc4ccccc4c23"))             # ethanol
